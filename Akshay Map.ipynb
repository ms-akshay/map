# %%
import folium

# %%
lwmap = folium.Map(location= [28.071777 , 78.747347], zoom_start = 13,tiles = "Stamen Toner" )

# %%
folium.Marker(location = [ 28.071777 , 78.747347], popup = "My_Home", icon = folium.Icon(color= "darkblue", icon = "tint", icon_color="red")).add_to(lwmap)

# %%
lwmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd

# %%
dataset= pd.read_excel("waterwatch_clean2.xlsx")

# %%
dataset.head(2)
# Out:
#    Unnamed: 0   Suburb  Number of single-residential properties_number  \
# 0           0  ATHLONE                                            2272
# 1           1   AURORA                                             426
#
#    Oct 2017\nkl/month    Month  Year   Latitude  Longitude
# 0                  11  October  2017 -33.967220  18.502140
# 1                  10  October  2017 -32.705958  18.485135

# %%
newmap = folium.Map(location= [-33.967220, 18.502140], zoom_start= 12)

# %%
folium.Marker(location = [-33.967220, 18.502140 ], popup = "My_Home", icon = folium.Icon(color= "darkblue", icon = "tint", icon_color="red")).add_to(newmap)

# %%
newmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
place = dataset[["Latitude", "Longitude"]]

# %%
type(place)
# Out:
# pandas.core.frame.DataFrame

# %%
place = place.values.tolist()

# %%
for point in place:
    folium.Marker(location= point).add_to(newmap)

# %%
newmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
